# %%
import pickle

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
# Loading data
df = pd.read_csv("mumbai.csv")
#Preprocessing
df = df[~(df['type_of_building'] == 'Individual House')]
df["Balcony"] = df["Balcony"].fillna(0)
mode = df["Furnished_status"].mode()
df["Furnished_status"] = df["Furnished_status"].fillna(mode)
df["parking"] = df["parking"].fillna(0)
plt.scatter(df["area"],df["price"])
plt.show()
# making regression model
reg = linear_model.LinearRegression()
reg.fit(df[['area','Bedrooms','Bathrooms','Balcony','parking']],df["price"])
#prediction
reg.predict([[1200,2,2,2,2]])
# Out:
# C:\Users\Ashish Yadav\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([21395729.78259449])

# %%
with open('model_pickle','wb') as file:
    pickle.dump(reg,file)

# %%
with open('model_pickle','rb') as file:
    mp = pickle.load(file)
mp.predict([[1200,2,2,2,2]])
# Out:
# C:\Users\Ashish Yadav\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([21395729.78259449])
